# %%
import cv2
import numpy as np
import face_recognition as fr

# %%
import sys
# !{sys.executable} -m pip install opencv-python

# %%
import cv2
import numpy as np
import face_recognition as fr

print(cv2.__version__)
# Out:
# 5.0.0

# %%
import sys
# !{sys.executable} -m pip install face-recognition
# Out:
# ...
#   Using cached dlib-20.0.1.tar.gz (3.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build dlib
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [102 lines of output]
#   INFO:root:running bdist_wheel
#   INFO:root:running build
#   INFO:root:running build_ext
#   Building extension for Python 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]
# ...

# %%
import sys

# !{sys.executable} -m pip install dlib-bin

# %%
# !{sys.executable} -m pip install face-recognition --no-deps

# %%
import cv2
import numpy as np
import face_recognition as fr

print("OpenCV:", cv2.__version__)
print("Face Recognition: OK")
# Out:
# OpenCV: 5.0.0
# Face Recognition: OK

# %%
import cv2
import numpy as np
import dlib
import face_recognition as fr

print("OpenCV:", cv2.__version__)
print("dlib:", dlib.__version__)
print("face_recognition: OK")
# Out:
# OpenCV: 5.0.0
# dlib: 20.0.1
# face_recognition: OK

# %%
import sys
# !{sys.executable} -m pip install face_recognition_models

# %%
import sys
# !{sys.executable} -m pip install face-recognition --no-deps

# %%
import sys
# !{sys.executable} -m pip install face-recognition-models

# %%
import cv2
import numpy as np
import dlib
import face_recognition as fr

print("OpenCV:", cv2.__version__)
print("dlib:", dlib.__version__)
print("face_recognition:", fr.__version__)
# Out:
# OpenCV: 5.0.0
# dlib: 20.0.1
# face_recognition: 1.2.3

# %%
import cv2
import numpy as np
import face_recognition as fr

# %%
video_capture=cv2.VideoCapture(0)

# %%
image = fr.load_image_file(r'C:\Users\Admin\Pictures\Camera Roll\WIN_20260901_12_39_01_Pro.jpg')

# %%
image_face_encoding=fr.face_encodings(image)[0]

# %%
known_face_encodings=[image_face_encoding]

# %%
known_face_names = ["ishi"]

# %%
while True:
    ret,frame=video_capture.read()
    
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    fc_locations=fr.face_locations(rgb_frame)
    face_encodings=fr.face_encodings(rgb_frame,fc_locations)
    
    for(top,right,bottom,left),face_encoding in zip(fc_locations,face_encodings):
        
        matches=fr.compare_faces(known_face_encodings,face_encoding)
        name="unknown"
        
        fc_distances=fr.face_distance(known_face_encodings,face_encoding)
        match_index = np.argmin(fc_distances)
       
        if matches[match_index]:
            name = known_face_names[match_index]
        
        cv2.rectangle(frame, (left, top), (right, bottom), (0,0,255), 2)
        
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0,0,255), cv2.FILLED)
        
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(frame,name,(left+6,bottom-6),font,1.0,(255,255,255),1)
    
    cv2.imshow('Simplelearn face detection system', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 6
#       2     ret,frame=video_capture.read()
#       3
#       4     rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#       5
# ----> 6     fc_locations=fr.face_locations(rgb_frame)
#       7     face_encodings=fr.face_encodings(rgb_frame,fc_locations)
#       8
#       9     for(top,right,bottom,left),face_encoding in zip(fc_locations,face_encodings):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\face_recognition\api.py:121, in face_locations(img, number_of_times_to_upsample, model)
#     119     return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     120 else:
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Admin
